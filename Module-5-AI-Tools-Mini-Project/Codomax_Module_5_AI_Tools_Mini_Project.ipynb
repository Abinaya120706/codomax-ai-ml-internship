# %% [markdown]
# Codomax Internship – Module 5
#
# AI Tools & Mini Project
#
# Project Title
#
# AI-Powered Student Study Assistant
#
# Objective
#
# The objective of this project is to explore Artificial Intelligence tools and understand how they can assist with coding, research, learning, and productivity.
#
# As part of this module, an AI-powered Student Study Assistant is developed to provide students with study guidance based on their selected topic.
#
# AI Tools Explored
#
# - ChatGPT
# - Google Gemini
# - Microsoft Copilot
#
# Technologies Used
#
# - Python
# - Artificial Intelligence
# - Google Colab
# - GitHub
#
# Project Goal
#
# The application provides simple study assistance and demonstrates how AI can be integrated into a practical student-focused application.

# %% [markdown]
# 1. AI Tools Exploration
#
# ChatGPT
#
# ChatGPT was explored as an AI assistant for coding, research, learning, debugging, and documentation.
#
# Google Gemini
#
# Google Gemini was explored for research, brainstorming, learning technical concepts, and comparing possible approaches to solving problems.
#
# Microsoft Copilot
#
# Microsoft Copilot was explored for coding assistance, productivity, and understanding alternative programming approaches.
#
# Key Learning
#
# AI tools can help improve productivity by assisting with coding, research, brainstorming, debugging, and documentation. However, AI-generated information and code should always be reviewed and tested before being used.

# %%
print("AI-Powered Student Study Assistant")
print("-----------------------------------")
print("Application started successfully!")
# Out:
# AI-Powered Student Study Assistant
# -----------------------------------
# Application started successfully!

# %%
study_topics = {
    "python": {
        "description": "Python is a beginner-friendly programming language widely used in AI and data science.",
        "steps": [
            "Learn variables and data types",
            "Practice if-else statements",
            "Learn loops",
            "Learn functions",
            "Practice lists and dictionaries"
        ]
    },

    "machine learning": {
        "description": "Machine Learning allows computers to learn patterns from data.",
        "steps": [
            "Understand supervised and unsupervised learning",
            "Learn training and testing data",
            "Study classification and regression",
            "Learn Scikit-learn",
            "Build a beginner ML project"
        ]
    },

    "artificial intelligence": {
        "description": "Artificial Intelligence focuses on creating systems that can perform tasks requiring human-like intelligence.",
        "steps": [
            "Understand AI concepts",
            "Learn Machine Learning",
            "Explore Deep Learning",
            "Study real-world AI applications",
            "Build a simple AI project"
        ]
    },

    "data science": {
        "description": "Data Science involves collecting, cleaning, analyzing, and interpreting data.",
        "steps": [
            "Learn Python",
            "Learn NumPy",
            "Learn Pandas",
            "Learn data visualization",
            "Practice data analysis projects"
        ]
    }
}

print("Study topics loaded successfully!")
# Out:
# Study topics loaded successfully!

# %%
def study_assistant(topic):
    topic = topic.lower().strip()

    if topic in study_topics:
        information = study_topics[topic]

        print("\nTopic:", topic.title())
        print("\nOverview:")
        print(information["description"])

        print("\nRecommended Study Plan:")

        for number, step in enumerate(information["steps"], start=1):
            print(f"{number}. {step}")

    else:
        print("\nSorry, this topic is not available.")
        print("Available topics:")

        for available_topic in study_topics:
            print("-", available_topic.title())

# %%
topic = input("Enter a topic you want to study: ")

study_assistant(topic)
# Out:
# Enter a topic you want to study: Machine Learning
#
# Topic: Machine Learning
#
# Overview:
# Machine Learning allows computers to learn patterns from data.
#
# Recommended Study Plan:
# 1. Understand supervised and unsupervised learning
# 2. Learn training and testing data
# 3. Study classification and regression
# 4. Learn Scikit-learn
# 5. Build a beginner ML project

# %%
def study_time_recommendation(hours):
    if hours <= 1:
        return "Focus on one important concept and complete a short practice session."

    elif hours <= 3:
        return "Divide your time between learning, practice, and revision."

    else:
        return "Use a structured schedule with learning, practice, revision, and breaks."

# %%
hours = float(input("How many hours can you study today? "))

print("\nStudy Time Recommendation:")
print(study_time_recommendation(hours))
# Out:
# How many hours can you study today? 2
#
# Study Time Recommendation:
# Divide your time between learning, practice, and revision.

# %%
def productivity_tip():
    tips = [
        "Break large tasks into smaller tasks.",
        "Set a clear study goal before starting.",
        "Take short breaks during long study sessions.",
        "Practice what you learn instead of only reading.",
        "Review difficult topics regularly."
    ]

    import random

    return random.choice(tips)

print("\nAI Study Productivity Tip:")
print(productivity_tip())
# Out:
# AI Study Productivity Tip:
# Take short breaks during long study sessions.

# %%
import random

STUDY_TOPICS = {
    "python": {
        "description": "Python is a programming language widely used in AI and Data Science.",
        "steps": [
            "Learn variables and data types",
            "Practice if-else statements",
            "Learn loops",
            "Learn functions",
            "Practice lists and dictionaries"
        ]
    },

    "machine learning": {
        "description": "Machine Learning allows computers to learn patterns from data.",
        "steps": [
            "Understand supervised and unsupervised learning",
            "Learn training and testing data",
            "Study classification and regression",
            "Learn Scikit-learn",
            "Build a beginner ML project"
        ]
    },

    "artificial intelligence": {
        "description": "Artificial Intelligence focuses on building systems that perform intelligent tasks.",
        "steps": [
            "Understand AI basics",
            "Learn Machine Learning",
            "Explore Deep Learning",
            "Study real-world AI applications",
            "Build a simple AI project"
        ]
    },

    "data science": {
        "description": "Data Science involves collecting, cleaning, analyzing and interpreting data.",
        "steps": [
            "Learn Python",
            "Learn NumPy",
            "Learn Pandas",
            "Learn data visualization",
            "Build a data analysis project"
        ]
    }
}


def study_assistant(topic):

    topic = topic.lower().strip()

    if topic in STUDY_TOPICS:

        information = STUDY_TOPICS[topic]

        print("\n" + "=" * 50)
        print(f"STUDY GUIDANCE: {topic.title()}")
        print("=" * 50)

        print("\nOverview:")
        print(information["description"])

        print("\nRecommended Study Plan:")

        for number, step in enumerate(information["steps"], start=1):
            print(f"{number}. {step}")

    else:

        print("\nTopic not found.")

        print("\nAvailable topics:")

        for available_topic in STUDY_TOPICS:
            print("-", available_topic.title())


def study_time_recommendation(hours):

    if hours <= 1:
        return "Focus on one important concept and complete a short practice session."

    elif hours <= 3:
        return "Divide your time between learning, practice and revision."

    else:
        return "Use a structured schedule with learning, practice, revision and breaks."


def productivity_tip():

    tips = [
        "Break large tasks into smaller tasks.",
        "Set a clear study goal before starting.",
        "Practice what you learn instead of only reading.",
        "Take short breaks during long study sessions.",
        "Review difficult topics regularly."
    ]

    return random.choice(tips)


def run_study_assistant():

    print("\n==========================================")
    print("   AI-POWERED STUDENT STUDY ASSISTANT")
    print("==========================================")

    print("\nAvailable topics:")

    for topic in STUDY_TOPICS:
        print("-", topic.title())

    topic = input("\nEnter the topic you want to study: ")

    study_assistant(topic)

    try:

        hours = float(input("\nHow many hours can you study today? "))

        if hours > 0:
            print("\nStudy Recommendation:")
            print(study_time_recommendation(hours))
        else:
            print("Please enter a positive number.")

    except ValueError:
        print("Please enter a valid number.")

    print("\nProductivity Tip:")
    print(productivity_tip())

    print("\nThank you for using the Student Study Assistant!")


run_study_assistant()
# Out:
# ==========================================
#    AI-POWERED STUDENT STUDY ASSISTANT
# ==========================================
#
# Available topics:
# - Python
# - Machine Learning
# - Artificial Intelligence
# - Data Science
#
# Enter the topic you want to study: python
#
# ==================================================
# STUDY GUIDANCE: Python
# ==================================================
#
# Overview:
# Python is a programming language widely used in AI and Data Science.
#
# Recommended Study Plan:
# 1. Learn variables and data types
# 2. Practice if-else statements
# 3. Learn loops
# 4. Learn functions
# 5. Practice lists and dictionaries
#
# How many hours can you study today? 1
#
# Study Recommendation:
# Focus on one important concept and complete a short practice session.
#
# Productivity Tip:
# Review difficult topics regularly.
#
# Thank you for using the Student Study Assistant!
